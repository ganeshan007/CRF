# %%
import pandas as pd
from collections import defaultdict
df=pd.read_csv('a2g_valid.csv')
a=df['ID'].str.split('_')
l=[k[0] for k in a]
df['hello']=l
df.head()
id_list=list(df['ID'])
id_set=set()
tag_set=set()
speaker_set=set()
for i in id_list:
    k=i.split('_')
    id_set.add(k[0])
print(id_set)
# print(id_dict)
# corpus = defaultdict(lambda: defaultdict(list))
# for idx in id_set:
#     l=list(df[df['hello']==str(idx)]['Utterance'])
#     l1=list(df[df['hello']==str(idx)]['Type'])
#     l2=list(df[df['hello']==str(idx)]['Dialog_Act'])
#     corpus[idx]['sentence']=l
#     corpus[idx]['speaker']=l1
#     corpus[idx]['tag']=l2
#     speaker_set.update(set(l1))
#     tag_set.update(set(l2))
# Out:
# {'95', '177', '120', '121', '108', '129', '132', '77', '13', '195', '46'}

# %%
a=df['ID'].str.split('_')
l=[k[0] for k in a]
df['hello']=l
df[df['hello']=='3']
# Out:
#         ID Type                                          Utterance Dialog_Act  \
# 7937   3_0    T                      Hello. Sam How you are doing?         gt
# 7938   3_1    P                             I'm good. HOw are you?         gt
# 7939   3_2    T  I'm doing well. Thanks for asking. So you're h...        ack
# 7940   3_3    P                        Yeah. My boss sent me over.        ack
# 7941   3_4    T                              your boss said, Sure?        crq
# 7942   3_5    P  There was this issue with a couple of the peop...         cd
# 7943   3_6    T  she wants you to come over and talk about your...        irq
# 7944   3_7    P  Um, I think more just so that, you know, my id...         id
# 7945   3_8    T  Okay, what would you mean by higher, like, you...        crq
# 7946   3_9    P  are higher, you know, just a little bit more i...         cd
# 7947  3_10    T  Okay, so they were unable to reach your level ...        irq
# 7948  3_11    P  Yeah. Yeah. Um, I think it's good, you know, s...         id
# 7949  3_12    T  Again, you stay at their level. So are you mea...        crq
# 7950  3_13    P  yeah, they're just they haven't they haven't a...         cd
# 7951  3_14    T  Okay, so counseling can help you bridge that g...         gc
# 7952  3_15    P  Yeah, so I think you know, so I can even bette...         gc
# 7953  3_16    T       When you say you're here at the first level,         gc
# 7954  3_17    P  maybe like a seven but I want to like blow it ...         gc
# 7955  3_18    T          How would you plan on accomplishing that?        irq
# 7956  3_19    P  Well, you know, I'm always getting recruited f...         id
# 7957  3_20    T  Okay, so it sounds like you're you have a lot ...         yq
# 7958  3_21    P                                        Yeah, yeah.        ack
# 7959  3_22    T  And maybe, from your understanding that people...        orq
# 7960  3_23    P  Yeah. You know, like, sometimes people just, i...         od
# 7961  3_24    T  So calcium help you to relate to them in a way...        irq
# 7962  3_25    P  Would they say? I think they would say that I ...         id
# 7963  3_26    T                                Would It be easier?         yq
# 7964  3_27    P  Yeah, you know, easier, better, more people. I...        ack
# 7965  3_28    T  All those stuff. That's what your coworkers wo...         yq
# 7966  3_29    P                                              Yeah,        ack
# 7967  3_30    T         yeah. Things that maybe detract from them.         gc
# 7968  3_31    P  Right. Like if you know, if I was doing the sa...         id
# 7969  3_32    T  does it frustrates you that you're not calling...        irq
# 7970  3_33    P  You're not recognized sometimes, but I've gott...         id
# 7971  3_34    T            So they recognize you most of the time.        crq
# 7972  3_35    P                   No I mean most of the time. Yeah         cd
# 7973  3_36    T  How long have you been with this particular em...        irq
# 7974  3_37    P  Um, maybe like six months, six months, maybe? ...         id
# 7975  3_38    T  Can you tell me about the job you've had prior...        irq
# 7976  3_39    P  an AI algorithm. They, so I got it, I got it t...         id
# 7977  3_40    T  You want to you want to shoot higher. You want...         yq
# 7978  3_41    P                                              Yeah.        ack
# 7979  3_42    T  more. So more stuff. You've already achieved s...         yq
# 7980  3_43    P                                              Yeah.        ack
# 7981  3_44    T  Alright, so your last ploy or the one before t...        irq
# 7982  3_45    P                                  Um, well, I mean,         gc
# 7983  3_46    T  So you initiate it and you quit. At the same t...         gc
# 7984  3_47    P  They just said I you know, I talked too much o...         id
# 7985  3_48    T          So I have to quit the pursuit you to come         id
# 7986  3_49    P  yet for them again. Yeah. Which I told them wa...         gc
# 7987  3_50    T                   You predicted that when you left        irq
# 7988  3_51    P  Yeah, it was like you're gonna you're gonna mi...         id
# 7989  3_52    T    So what did you tell them when they offered you        irq
# 7990  3_53    P  the chargeback that I was had gotten a phenome...         id
# 7991  3_54    T          So you rejected them at that point, okay.        crq
# 7992  3_55    P  Yeah. And I, you know, I want to make my boss ...         cd
# 7993  3_56    T  It's your boss putting, I mean, she encouraged...         id
# 7994  3_57    P  I think it's strongly encouraged. I think she ...         od
# 7995  3_58    T  So she's trying to help you for the future. An...         yq
# 7996  3_59    P                              Yeah. Sure. Thank you        ack
#
#      Dialog_Act_1 Emotion hello
# 7937          NaN     NaN     3
# 7938          NaN     NaN     3
# 7939           yq     NaN     3
# 7940          NaN     NaN     3
# 7941          NaN     NaN     3
# 7942           id     NaN     3
# 7943          NaN     NaN     3
# 7944          NaN     NaN     3
# 7945          NaN     NaN     3
# 7946          NaN     NaN     3
# 7947          NaN     NaN     3
# 7948          NaN     NaN     3
# 7949          NaN     NaN     3
# 7950          NaN     NaN     3
# 7951          NaN     NaN     3
# 7952          NaN     NaN     3
# 7953          NaN     NaN     3
# 7954          NaN     NaN     3
# 7955          NaN     NaN     3
# 7956          NaN     NaN     3
# 7957          NaN     NaN     3
# 7958          NaN     NaN     3
# 7959          NaN     NaN     3
# 7960          NaN     NaN     3
# 7961          NaN     NaN     3
# 7962          NaN     NaN     3
# 7963          NaN     NaN     3
# 7964          NaN     NaN     3
# 7965          NaN     NaN     3
# 7966          NaN     NaN     3
# 7967          NaN     NaN     3
# 7968          NaN     NaN     3
# 7969          NaN     NaN     3
# 7970          NaN     NaN     3
# 7971          NaN     NaN     3
# 7972          NaN     NaN     3
# 7973          NaN     NaN     3
# 7974          NaN     NaN     3
# 7975          NaN     NaN     3
# 7976          NaN     NaN     3
# 7977          NaN     NaN     3
# 7978          NaN     NaN     3
# 7979          NaN     NaN     3
# 7980          NaN     NaN     3
# 7981          NaN     NaN     3
# 7982          NaN     NaN     3
# 7983          NaN     NaN     3
# 7984          NaN     NaN     3
# 7985          NaN     NaN     3
# 7986          NaN     NaN     3
# 7987          NaN     NaN     3
# 7988          NaN     NaN     3
# 7989          NaN     NaN     3
# 7990          NaN     NaN     3
# 7991          NaN     NaN     3
# 7992           id     NaN     3
# 7993          orq     NaN     3
# 7994          NaN     NaN     3
# 7995          NaN     NaN     3
# 7996          NaN     NaN     3

# %%
print(len(tag_set))
# Out:
# 18
